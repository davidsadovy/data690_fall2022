# %% [markdown]
# <a href="https://colab.research.google.com/github/davidsadovy/data690_fall2022/blob/main/assignment_08/in_class_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oct 20 In-class Practice
#
# Student survey data analysis and visualization.

# %%
import re
import pandas as pd
import plotly.express as px

pd.set_option("display.max_colwidth", None)

# %%
DATA_SOURCE = "https://raw.githubusercontent.com/davidsadovy/python-stats-dataviz/master/data/DATA690_FALL2022_Survey.csv"

df = pd.read_csv(DATA_SOURCE)

df.shape
# Out:
# (23, 13)

# %%
df.head()
# Out:
#                    Timestamp           1. My primary educational background  \
# 0  2022/08/31 2:44:42 PM AST  STEM (Science, Technology, Engineering, Math)
# 1  2022/08/31 3:10:34 PM AST  STEM (Science, Technology, Engineering, Math)
# 2  2022/08/31 3:11:14 PM AST  STEM (Science, Technology, Engineering, Math)
# 3  2022/08/31 4:42:40 PM AST  STEM (Science, Technology, Engineering, Math)
# 4  2022/08/31 4:44:08 PM AST  STEM (Science, Technology, Engineering, Math)
#
#         2. My primary job function  \
# 0  Technology/engineering-oriented
# 1                Full-time Student
# 2                Full-time Student
# 3  Technology/engineering-oriented
# 4  Technology/engineering-oriented
#
#   3. My level of computer programing knowledge  \
# 0                                 Intermediate
# 1                                     Beginner
# 2                                 Intermediate
# 3                                     Beginner
# 4                                     Beginner
#
#   4. My level of Python progrmming knowledge  \
# 0                               Intermediate
# 1                                   Beginner
# 2                               Intermediate
# 3                                   Beginner
# 4                                   Beginner
#
#   5. My level of Statistics knowledge 6. My Familarity with GitHub  \
# 0                        Intermediate       I use GitHub regularly
# 1                            Beginner    I use GitHub occasionally
# 2                            Beginner           I don't use GitHub
# 3                            Beginner           I don't use GitHub
# 4                            Beginner           I don't use GitHub
#
#   7. My gender 8. My Birth Year  \
# 0       Female        1/11/1997
# 1       Female             1991
# 2       Female             2000
# 3         Male             1969
# 4       Female             1999
#
#   9. What do you enjoy doing in your leisure time?  \
# 0           I love doing yoga, dancing and cooking
# 1                                      watch movie
# 2                           Watch anime and songs
# 3                       This is it - take classes.
# 4                               Listening to music
#
#    10. What do you expect to get out of this course?  \
# 0  I want to learn visualization in an efficient ...
# 1  I want to understand the way to analyze and co...
# 2  Have good command using python for data viz an...
# 3  I know a little statistics and I know a little...
# 4          To have strong grip on python programming
#
#              11. What is your long-term career goal?  \
# 0  I want to be a data scientist in companies lik...
# 1                               To be Data Scientist
# 2                                     Data engineer
# 3                                 My 2nd retirement!
# 4                  To see myself as a data scientist
#
#               12. Other courses taking this semester
# 0  Special Topics in Data Science | DATA 690 - Ar...
# 1  Platforms for Big Data Processing | DATA 603;S...
# 2  IS 603 Decision Support Systems, IS 755 Data M...
# 3                                               None
# 4  Introduction to Data Science | DATA 601;Data M...

# %%
df_q12 = df[["12. Other courses taking this semester"]]

df_q12.head()
# Out:
#                                                                                             12. Other courses taking this semester
# 0  Special Topics in Data Science | DATA 690 - Artificial Intelligence Practice;ENMG 652 Management, Leadership and Communication
# 1            Platforms for Big Data Processing | DATA 603;Special Topics in Data Science | DATA 690 - Data Structures & Algorithms
# 2                                                                             IS 603 Decision Support Systems, IS 755 Data Mining
# 3                                                                                                                             None
# 4                                                               Introduction to Data Science | DATA 601;Data Management | DATA 604

# %% [markdown]
# ## Pay attention to the difference between the two:
#
# - df[["12. Other courses taking this semester"]]
# - df["12. Other courses taking this semester"]

# %%
other_courses = df["12. Other courses taking this semester"].tolist()

other_courses
# Out:
# ['Special Topics in Data Science | DATA 690 - Artificial Intelligence Practice;ENMG 652 Management, Leadership and Communication ',
#  'Platforms for Big Data Processing | DATA 603;Special Topics in Data Science | DATA 690 - Data Structures & Algorithms',
#  'IS 603 Decision Support Systems, IS 755 Data Mining ',
#  'None',
#  'Introduction to Data Science | DATA 601;Data Management | DATA 604',
#  'Ethical And Legal Issues in Data Science | DATA 605;Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Engineering Management 652, Cyber Security 620',
#  'Introduction to Data Science | DATA 601;Data Management | DATA 604',
#  'Introduction to Data Science | DATA 601;Data Management | DATA 604',
#  'Introduction to Data Science | DATA 601;Ethical And Legal Issues in Data Science | DATA 605',
#  'Platforms for Big Data Processing | DATA 603;Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'HIT 723- Public health Informatics, ENMG 650- Project management fundamentals ',
#  'Introduction to Data Science | DATA 601;ENMG - 652',
#  'Introduction to Data Science | DATA 601;Ethical And Legal Issues in Data Science | DATA 605',
#  'Introduction to Data Science | DATA 601;Ethical And Legal Issues in Data Science | DATA 605',
#  'Introduction to Data Science | DATA 601;Intro to Data Analysis and Machine Learning | DATA 602;Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Special Topics in Data Science | DATA 690 - Financial Data Science;DATA 690: Deep learning',
#  'Ethical And Legal Issues in Data Science | DATA 605;Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Introduction to Data Science | DATA 601;ENMG - 652',
#  'Ethical And Legal Issues in Data Science | DATA 605;Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Special Topics in Data Science | DATA 690 - Financial Data Science',
#  'Intro to Data Analysis and Machine Learning | DATA 602;Platforms for Big Data Processing | DATA 603;Special Topics in Data Science | DATA 690 - Data Structures & Algorithms']

# %%
# Intitialize the course_student_count dict with empty items
# This is similar to initialize a list with empty items: a_list = []


course_student_count = {}

for course_string in other_courses:         # first loop process student one at a time

    courses = re.split(r',|;', course_string)      # split the course string into a list of courses

    for course in courses:                  # second loop process courses taken by the student, one course at a time

        if course in course_student_count:  # if the course is already
            course_student_count[course] += 1

        else:
            course_student_count[course] = 1

course_student_count
# Out:
# {'Special Topics in Data Science | DATA 690 - Artificial Intelligence Practice': 1,
#  'ENMG 652 Management': 1,
#  ' Leadership and Communication ': 1,
#  'Platforms for Big Data Processing | DATA 603': 3,
#  'Special Topics in Data Science | DATA 690 - Data Structures & Algorithms': 2,
#  'IS 603 Decision Support Systems': 1,
#  ' IS 755 Data Mining ': 1,
#  'None': 1,
#  'Introduction to Data Science | DATA 601': 9,
#  'Data Management | DATA 604': 3,
#  'Ethical And Legal Issues in Data Science | DATA 605': 6,
#  'Special Topics in Data Science | DATA 690 - Financial Data Science': 8,
#  'Engineering Management 652': 1,
#  ' Cyber Security 620': 1,
#  'HIT 723- Public health Informatics': 1,
#  ' ENMG 650- Project management fundamentals ': 1,
#  'ENMG - 652': 2,
#  'Intro to Data Analysis and Machine Learning | DATA 602': 2,
#  'DATA 690: Deep learning': 1}

# %%
df_course_count = pd.DataFrame(course_student_count.items(), columns=["Course Name", "Students"])

df_course_count
# Out:
#                                                                      Course Name  \
# 0   Special Topics in Data Science | DATA 690 - Artificial Intelligence Practice
# 1                                                            ENMG 652 Management
# 2                                                  Leadership and Communication
# 3                                   Platforms for Big Data Processing | DATA 603
# 4       Special Topics in Data Science | DATA 690 - Data Structures & Algorithms
# 5                                                IS 603 Decision Support Systems
# 6                                                            IS 755 Data Mining
# 7                                                                           None
# 8                                        Introduction to Data Science | DATA 601
# 9                                                     Data Management | DATA 604
# 10                           Ethical And Legal Issues in Data Science | DATA 605
# 11            Special Topics in Data Science | DATA 690 - Financial Data Science
# 12                                                    Engineering Management 652
# 13                                                            Cyber Security 620
# 14                                            HIT 723- Public health Informatics
# 15                                    ENMG 650- Project management fundamentals
# 16                                                                    ENMG - 652
# 17                        Intro to Data Analysis and Machine Learning | DATA 602
# 18                                                       DATA 690: Deep learning
#
#     Students
# 0          1
# 1          1
# 2          1
# 3          3
# 4          2
# 5          1
# 6          1
# 7          1
# 8          9
# 9          3
# 10         6
# 11         8
# 12         1
# 13         1
# 14         1
# 15         1
# 16         2
# 17         2
# 18         1

# %% [markdown]
# # Data Cleansing

# %%
def remove_special_topic(course_name):
    if course_name.startswith("Special Topics"):
        return course_name.split("|")[1]
    else:
        return course_name

test_course = "Special Topics in Data Science | DATA 690 - Financial Data Science"

remove_special_topic(test_course)
# Out:
# ' DATA 690 - Financial Data Science'

# %%
df_course_count["cleansed_course_name"] = df_course_count["Course Name"].apply(remove_special_topic)

df_course_count
# Out:
#                                                                      Course Name  \
# 0   Special Topics in Data Science | DATA 690 - Artificial Intelligence Practice
# 1                                                            ENMG 652 Management
# 2                                                  Leadership and Communication
# 3                                   Platforms for Big Data Processing | DATA 603
# 4       Special Topics in Data Science | DATA 690 - Data Structures & Algorithms
# 5                                                IS 603 Decision Support Systems
# 6                                                            IS 755 Data Mining
# 7                                                                           None
# 8                                        Introduction to Data Science | DATA 601
# 9                                                     Data Management | DATA 604
# 10                           Ethical And Legal Issues in Data Science | DATA 605
# 11            Special Topics in Data Science | DATA 690 - Financial Data Science
# 12                                                    Engineering Management 652
# 13                                                            Cyber Security 620
# 14                                            HIT 723- Public health Informatics
# 15                                    ENMG 650- Project management fundamentals
# 16                                                                    ENMG - 652
# 17                        Intro to Data Analysis and Machine Learning | DATA 602
# 18                                                       DATA 690: Deep learning
#
#     Students                                    cleansed_course_name
# 0          1             DATA 690 - Artificial Intelligence Practice
# 1          1                                     ENMG 652 Management
# 2          1                           Leadership and Communication
# 3          3            Platforms for Big Data Processing | DATA 603
# 4          2                 DATA 690 - Data Structures & Algorithms
# 5          1                         IS 603 Decision Support Systems
# 6          1                                     IS 755 Data Mining
# 7          1                                                    None
# 8          9                 Introduction to Data Science | DATA 601
# 9          3                              Data Management | DATA 604
# 10         6     Ethical And Legal Issues in Data Science | DATA 605
# 11         8                       DATA 690 - Financial Data Science
# 12         1                              Engineering Management 652
# 13         1                                      Cyber Security 620
# 14         1                      HIT 723- Public health Informatics
# 15         1              ENMG 650- Project management fundamentals
# 16         2                                              ENMG - 652
# 17         2  Intro to Data Analysis and Machine Learning | DATA 602
# 18         1                                 DATA 690: Deep learning

# %%
df_sorted = df_course_count.sort_values(by="Students", ascending=False)

# %%
fig = px.bar(
    df_sorted, 
    x="cleansed_course_name", 
    y="Students", 
    title="Courses Taken with Counts", 
    color="cleansed_course_name", 
    template="presentation"
    )

# legend is redundant, so remove it
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="81d11cec-e3ff-4821-87e9-8583f8fbf0e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81d11cec-e3ff-4821-87e9-8583f8fbf0e7")) {                    Plotly.newPlot(                        "81d11cec-e3ff-4821-87e9-8583f8fbf0e7",                        [{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"Introduction to Data Science | DATA 601","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Introduction to Data Science | DATA 601","offsetgroup":"Introduction to Data Science | DATA 601","orientation":"v","showlegend":true,"textposition":"auto","x":["Introduction to Data Science | DATA 601"],"xaxis":"x","y":[9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":" DATA 690 - Financial Data Science","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":" DATA 690 - Financial Data Science","offsetgroup":" DATA 690 - Financial Data Science","orientation":"v","showlegend":true,"textposition":"auto","x":[" DATA 690 - Financial Data Science"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"Ethical And Legal Issues in Data Science | DATA 605","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Ethical And Legal Issues in Data Science | DATA 605","offsetgroup":"Ethical And Legal Issues in Data Science | DATA 605","orientation":"v","showlegend":true,"textposition":"auto","x":["Ethical And Legal Issues in Data Science | DATA 605"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"Data Management | DATA 604","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Data Management | DATA 604","offsetgroup":"Data Management | DATA 604","orientation":"v","showlegend":true,"textposition":"auto","x":["Data Management | DATA 604"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"Platforms for Big Data Processing | DATA 603","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Platforms for Big Data Processing | DATA 603","offsetgroup":"Platforms for Big Data Processing | DATA 603","orientation":"v","showlegend":true,"textposition":"auto","x":["Platforms for Big Data Processing | DATA 603"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"Intro to Data Analysis and Machine Learning | DATA 602","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Intro to Data Analysis and Machine Learning | DATA 602","offsetgroup":"Intro to Data Analysis and Machine Learning | DATA 602","orientation":"v","showlegend":true,"textposition":"auto","x":["Intro to Data Analysis and Machine Learning | DATA 602"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":" DATA 690 - Data Structures & Algorithms","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":" DATA 690 - Data Structures & Algorithms","offsetgroup":" DATA 690 - Data Structures & Algorithms","orientation":"v","showlegend":true,"textposition":"auto","x":[" DATA 690 - Data Structures & Algorithms"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cleansed_course_name=%{x}<br>Students=%{y}<extra></extra>","legendgroup":"ENMG - 652","ma ...
