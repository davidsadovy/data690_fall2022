# %% [markdown]
# <a href="https://colab.research.google.com/github/davidsadovy/data690_fall2022/blob/main/assignment_08/assignment_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 08
#
# - Dave Sadovy
# - 10/23/2022

# %% [markdown]
# 1. Use Pandas to read the file census_costs.txt.
# 2. Find out how many rows and columns it has.
# 3. Display first 10, last 10, and random 10 rows.
# 4. Find out the data types of all columns - use `info()` function.
# 5. Find out the summary statistics of all columns.
# 6. Cleanse the data to make the year, population, cost, cost per person numerical type.
# - Code functions to cleanse the columns. One function for one column.
# - Use `apply()` method of data frame to apply the functions to the columns for data cleansing.
# 7. Find out the summary statistics of the numerical columns - use `describe()` function.
# 8. Use Plotly to plot the average cost per person over time.
# 9. Use Plotly to plot the scatter plot of Total Population vs Total Cost.

# %% [markdown]
# ## Step 0 - Import required libraries.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Step 1 - Use Pandas to read the file census_costs.txt.

# %%
DATA_SOURCE = "https://raw.githubusercontent.com/davidsadovy/python-stats-dataviz/master/assignments/assignment_08_census_cost/census_costs.txt"

df = pd.read_csv(DATA_SOURCE, skiprows=1, sep="\t")

df
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person
# 0         1790        3,929,214         $44,377              1.13 cents
# 1         1800        5,308,483         $66,109              1.24 cents
# 2         1810        7,239,881        $178,445              2.46 cents
# 3         1820        9,633,822        $208,526              2.16 cents
# 4         1830       12,866,020        $378,545              2.94 cents
# 5         1840       17,069,458        $833,371              4.88 cents
# 6         1850       23,191,876      $1,423,351              6.14 cents
# 7         1860       31,443,321      $1,969,377              6.26 cents
# 8         1870       38,558,371      $3,421,198              8.87 cents
# 9         1880       50,155,783      $5,790,678             11.54 cents
# 10        1890       62,979,766     $11,547,127             18.33 cents
# 11        1900       76,303,387     $11,854,000             15.54 cents
# 12        1910       91,972,266     $15,968,000             17.07 cents
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 15        1940      131,669,275     $67,527,000             51.29 cents
# 16        1950      151,325,798     $91,462,000             60.44 cents
# 17        1960      179,323,175    $127,934,000             71.34 cents
# 18        1970      203,302,031    $247,653,000                   $1.22
# 19        1980      226,542,199  $1,078,488,000                   $4.76
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 22       2010*      308,745,538     $13 Billion                  $42.11

# %% [markdown]
# ## Step 2 - Find out how many rows and columns it has.

# %%
df.shape
# Out:
# (23, 4)

# %% [markdown]
# ## Step 3 - Display first 10, last 10, and random 10 rows.

# %%
df.head(10)
# Out:
#   Census Year Total Population Census Cost Average Cost Per Person
# 0        1790        3,929,214     $44,377              1.13 cents
# 1        1800        5,308,483     $66,109              1.24 cents
# 2        1810        7,239,881    $178,445              2.46 cents
# 3        1820        9,633,822    $208,526              2.16 cents
# 4        1830       12,866,020    $378,545              2.94 cents
# 5        1840       17,069,458    $833,371              4.88 cents
# 6        1850       23,191,876  $1,423,351              6.14 cents
# 7        1860       31,443,321  $1,969,377              6.26 cents
# 8        1870       38,558,371  $3,421,198              8.87 cents
# 9        1880       50,155,783  $5,790,678             11.54 cents

# %%
df.tail(10)
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 15        1940      131,669,275     $67,527,000             51.29 cents
# 16        1950      151,325,798     $91,462,000             60.44 cents
# 17        1960      179,323,175    $127,934,000             71.34 cents
# 18        1970      203,302,031    $247,653,000                   $1.22
# 19        1980      226,542,199  $1,078,488,000                   $4.76
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 22       2010*      308,745,538     $13 Billion                  $42.11

# %%
df.sample(10)
# Out:
#    Census Year Total Population   Census Cost Average Cost Per Person
# 4         1830       12,866,020      $378,545              2.94 cents
# 12        1910       91,972,266   $15,968,000             17.07 cents
# 16        1950      151,325,798   $91,462,000             60.44 cents
# 3         1820        9,633,822      $208,526              2.16 cents
# 22       2010*      308,745,538   $13 Billion                  $42.11
# 21        2000      281,421,906  $4.5 Billion                  $15.99
# 7         1860       31,443,321    $1,969,377              6.26 cents
# 6         1850       23,191,876    $1,423,351              6.14 cents
# 13        1920      105,710,620   $25,117,000             23.76 cents
# 8         1870       38,558,371    $3,421,198              8.87 cents

# %% [markdown]
# ## Step 4 - Find out the data types of all columns - use `info()` function.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Census Year              23 non-null     object
#  1   Total Population         23 non-null     object
#  2   Census Cost              23 non-null     object
#  3   Average Cost Per Person  23 non-null     object
# dtypes: object(4)
# memory usage: 864.0+ bytes

# %% [markdown]
# ## Step 5 - Find out the summary statistics of all columns.

# %%
df.describe()
# Out:
#        Census Year Total Population Census Cost Average Cost Per Person
# count           23               23          23                      23
# unique          23               23          23                      23
# top           1790        3,929,214     $44,377              1.13 cents
# freq             1                1           1                       1

# %% [markdown]
# ## Step 6 - Cleanse the data to make the year, population, cost, cost per person numerical type.
# - Code functions to cleanse the columns. One function for one column.
# - Use `apply()` method of data frame to apply the functions to the columns for data cleansing.

# %%
def cleanse_year(a_string):
    '''Converts a string of numbers that may contain asterisks into an integer'''
    return int(a_string.replace("*", ""))

# %%
def cleanse_pop(a_string):
    '''Converts a string of numbers that may contain commas into an integer'''
    return int(a_string.replace(",", ""))

# %%
def cleanse_cost(a_string):
    '''Converts a string of numbers that may contain dollar signs, commas, 
       and/or the word "Billion" into an integer'''
    new_string = a_string.replace("$", "").replace(",", "")
    if new_string.endswith("Billion"):
        return int(float(new_string.split(" ")[0]) * 10**9)
    else:
        return int(new_string)

# %%
def cleanse_acpp(a_string):
    '''Converts a string of numbers that may contain dollar signs 
       and/or the word "cents" into an integer'''
    new_string = a_string.replace("$", "")
    if new_string.endswith("cents"):
        return float(new_string.split(" ")[0])/100
    else:
        return float(new_string)

# %%
df["Census Year (Cleansed)"] = df["Census Year"].apply(cleanse_year)
df["Total Population (Cleansed)"] = df["Total Population"].apply(cleanse_pop)
df["Census Cost (Cleansed)"] = df["Census Cost"].apply(cleanse_cost)
df["Average Cost Per Person (Cleansed)"] = df["Average Cost Per Person"].apply(cleanse_acpp)
df
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person  \
# 0         1790        3,929,214         $44,377              1.13 cents
# 1         1800        5,308,483         $66,109              1.24 cents
# 2         1810        7,239,881        $178,445              2.46 cents
# 3         1820        9,633,822        $208,526              2.16 cents
# 4         1830       12,866,020        $378,545              2.94 cents
# 5         1840       17,069,458        $833,371              4.88 cents
# 6         1850       23,191,876      $1,423,351              6.14 cents
# 7         1860       31,443,321      $1,969,377              6.26 cents
# 8         1870       38,558,371      $3,421,198              8.87 cents
# 9         1880       50,155,783      $5,790,678             11.54 cents
# 10        1890       62,979,766     $11,547,127             18.33 cents
# 11        1900       76,303,387     $11,854,000             15.54 cents
# 12        1910       91,972,266     $15,968,000             17.07 cents
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 15        1940      131,669,275     $67,527,000             51.29 cents
# 16        1950      151,325,798     $91,462,000             60.44 cents
# 17        1960      179,323,175    $127,934,000             71.34 cents
# 18        1970      203,302,031    $247,653,000                   $1.22
# 19        1980      226,542,199  $1,078,488,000                   $4.76
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 22       2010*      308,745,538     $13 Billion                  $42.11
#
#     Census Year (Cleansed)  Total Population (Cleansed)  \
# 0                     1790                      3929214
# 1                     1800                      5308483
# 2                     1810                      7239881
# 3                     1820                      9633822
# 4                     1830                     12866020
# 5                     1840                     17069458
# 6                     1850                     23191876
# 7                     1860                     31443321
# 8                     1870                     38558371
# 9                     1880                     50155783
# 10                    1890                     62979766
# 11                    1900                     76303387
# 12                    1910                     91972266
# 13                    1920                    105710620
# 14                    1930                    122775046
# 15                    1940                    131669275
# 16                    1950                    151325798
# 17                    1960                    179323175
# 18                    1970                    203302031
# 19                    1980                    226542199
# 20                    1990                    248718301
# 21                    2000                    281421906
# 22                    2010                    308745538
#
#     Census Cost (Cleansed)  Average Cost Per Person (Cleansed)
# 0                    44377                              0.0113
# 1                    66109                              0.0124
# 2                   178445                              0.0246
# 3                   208526                              0.0216
# 4                   378545                              0.0294
# 5                   833371                              0.0488
# 6                  1423351                              0.0614
# 7                  1969377                              0.0626
# 8                  3421198                              0.0887
# 9                  5790678                              0.1154
# 10                11547127                              0.1833
# 11                11854000                              0.1554
# 12                15968000                              0.1707
# 13                25117000                              0.2376
# 14                40156000                              0.3271
# 15                67527000                              0.5129
# 16                91462000                              0.6044
# 17               127934000                              0.7134
# 18               247653000                              1.2200
# 19              1078488000                              4.7600
# 20              2492830000                             10.0200
# 21              4500000000                             15.9900
# 22             13000000000                             42.1100

# %% [markdown]
# ## Step 7 - Find out the summary statistics of the numerical columns - use `describe()` function.

# %%
df.describe()
# Out:
#        Census Year (Cleansed)  Total Population (Cleansed)  \
# count                 23.0000                 2.300000e+01
# mean                1900.0000                 1.039211e+08
# std                   67.8233                 9.622629e+07
# min                 1790.0000                 3.929214e+06
# 25%                 1845.0000                 2.013067e+07
# 50%                 1900.0000                 7.630339e+07
# 75%                 1955.0000                 1.653245e+08
# max                 2010.0000                 3.087455e+08
#
#        Census Cost (Cleansed)  Average Cost Per Person (Cleansed)
# count            2.300000e+01                           23.000000
# mean             9.445587e+08                            3.368739
# std              2.830037e+09                            9.278241
# min              4.437700e+04                            0.011300
# 25%              1.128361e+06                            0.055100
# 50%              1.185400e+07                            0.170700
# 75%              1.096980e+08                            0.658900
# max              1.300000e+10                           42.110000

# %% [markdown]
# ## Step 8 - Use Plotly to plot the average cost per person over time.

# %%
fig = px.bar(
    df, 
    x="Census Year (Cleansed)", 
    y="Average Cost Per Person (Cleansed)", 
    title="Average Cost Per Person of the US Census, 1790-2010", 
    color="Census Year (Cleansed)", 
    template="presentation"
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d6234092-8f55-4c02-b975-f1d08ca628cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6234092-8f55-4c02-b975-f1d08ca628cd")) {                    Plotly.newPlot(                        "d6234092-8f55-4c02-b975-f1d08ca628cd",                        [{"alignmentgroup":"True","hovertemplate":"Census Year (Cleansed)=%{marker.color}<br>Average Cost Per Person (Cleansed)=%{y}<extra></extra>","legendgroup":"","marker":{"color":[1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000,2010],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000,2010],"xaxis":"x","y":[0.0113,0.0124,0.0246,0.0216,0.0294,0.048799999999999996,0.061399999999999996,0.0626,0.08869999999999999,0.11539999999999999,0.1833,0.15539999999999998,0.1707,0.2376,0.3271,0.5129,0.6043999999999999,0.7134,1.22,4.76,10.02,15.99,42.11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Census Year (Cleansed)"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Average Cost Per Person (Cleansed)"}},"coloraxis":{"colorbar":{"title":{"text":"Census Year (Cleansed)"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"legend":{"tracegroupgap":0},"title":{"text":"Average Cost Per Person of the US Census, 1790-2010"},"barmode":"relative"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('d6234092-8f55-4c02-b975-f1d08ca628cd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ## Step 9 - Use Plotly to plot the scatter plot of Total Population vs Total Cost.

# %%
fig = px.scatter(
    df, 
    x="Total Population (Cleansed)",
    y="Census Cost (Cleansed)", 
    title="US Census Population vs Cost, 1790-2010",  
    color="Average Cost Per Person (Cleansed)",
    template="plotly_dark"
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2216fc3b-1de4-4b48-ae1d-5894faa58e12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2216fc3b-1de4-4b48-ae1d-5894faa58e12")) {                    Plotly.newPlot(                        "2216fc3b-1de4-4b48-ae1d-5894faa58e12",                        [{"hovertemplate":"Total Population (Cleansed)=%{x}<br>Census Cost (Cleansed)=%{y}<br>Average Cost Per Person (Cleansed)=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.0113,0.0124,0.0246,0.0216,0.0294,0.048799999999999996,0.061399999999999996,0.0626,0.08869999999999999,0.11539999999999999,0.1833,0.15539999999999998,0.1707,0.2376,0.3271,0.5129,0.6043999999999999,0.7134,1.22,4.76,10.02,15.99,42.11],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3929214,5308483,7239881,9633822,12866020,17069458,23191876,31443321,38558371,50155783,62979766,76303387,91972266,105710620,122775046,131669275,151325798,179323175,203302031,226542199,248718301,281421906,308745538],"xaxis":"x","y":[44377,66109,178445,208526,378545,833371,1423351,1969377,3421198,5790678,11547127,11854000,15968000,25117000,40156000,67527000,91462000,127934000,247653000,1078488000,2492830000,4500000000,13000000000],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f" ...
